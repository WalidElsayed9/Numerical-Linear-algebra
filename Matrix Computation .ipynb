# %%
import numpy as np

# %%
a = np.array([[0.9,0.98,0.52,0.25],
             [0.24,0.6,0.4,0.69],
             [0,0,0.06,0.87],
             [0,0,0.33,0.005]])
x = np.array([0.2,0.03,0,0.99])
a.shape
x.shape
# Out:
# (4,)

# %%
a.T@x.T
# Out:
# array([0.1872 , 0.214  , 0.4427 , 0.07565])

# %%
a.T*x.T
# Out:
# array([[0.18   , 0.0072 , 0.     , 0.     ],
#        [0.196  , 0.018  , 0.     , 0.     ],
#        [0.104  , 0.012  , 0.     , 0.3267 ],
#        [0.05   , 0.0207 , 0.     , 0.00495]])

# %%
from IPython.display import Image
Image(filename='shop.png')

# %%
A = np.array([[6,5,3,1],
            [3,6,2,2],
            [3,4,3,1]])
B= np.array([[1.50,1.00],
           [2.00,2.50],
            [5.00,4.50],
           [16.00,17.00]])
A@B
# Out:
# array([[50. , 49. ],
#        [58.5, 61. ],
#        [43.5, 43.5]])
